# %% [markdown]
# <a href="https://www.kaggle.com/hasinisadunikasilva/skin-cancer-detection-with-dcnn?scriptVersionId=88060766" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# <a href="https://colab.research.google.com/github/HasiniSandunika/cancer-detection-with-cnn/blob/master/cancer_detection_cnn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import glob
import cv2
import re
import matplotlib.pyplot as plt
from keras.models import Sequential 
from keras.layers import Dense, Conv2D, MaxPool2D, Flatten 
import keras
from tensorflow.keras.optimizers import SGD
from keras.utils import np_utils
from keras.models import load_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import itertools

# %%
def define_model():
  model = Sequential()
  model.add(Conv2D(filters=4  ,kernel_size=(5,5), strides=(3,3), 
                  activation='relu', input_shape=(128,128,1))) 
  model.add(MaxPool2D(pool_size=(2,2), strides=(2,2)))   
  model.add(Conv2D(kernel_size=(5,5), strides=(2,2), 
                  filters=4  , activation='relu', input_shape=(21,21, 1))) 
  model.add(MaxPool2D(pool_size=(2,2), strides=(1,1)))
  model.add(Flatten())
  model.add(Dense(units=4, activation='tanh'))
  model.add(Dense(2, activation='softmax')) 
  print('\nCNN model : ')
  model.summary()
  return model

# %%
def compile_fit_model(model):
  print('\nTraining the dataset : ')
  OPTIMIZER = SGD(learning_rate=0.1)
  x_train_gs=np.load('../input/breast-cancer-detection-dcnn/train_dataset/x_train.npy')
  y_train_gs=np.load('../input/breast-cancer-detection-dcnn/train_dataset/y_train.npy')
  x_train, x_val, y_train, y_val = train_test_split(x_train_gs, y_train_gs,test_size=0.2,
                                                    random_state=15)
  model.compile(optimizer=OPTIMIZER, loss=keras.losses.categorical_crossentropy, metrics=['accuracy'])
  model_fit = model.fit(x=x_train, y=y_train, epochs=50,
                        batch_size=32, validation_data=(x_val, y_val),verbose=1)
                            
  print('Graph of epochs vs loss')
  # %matplotlib inline 
  plt.figure() 
  plt.xlabel('Epochs') 
  plt.ylabel('Loss') 
  plt.plot(model_fit.history['loss']) 
  plt.plot(model_fit.history['val_loss']) 
  plt.legend(['Training', 'Validation'])
  plt.figure() 
  plt.show()
  return model

# %%
def plot_normalized_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') /cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, with normalization')
    print(cm)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=55)
    plt.yticks(tick_marks, classes)
    fmt = '.2f'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# %%
def main():
    print('Training dataset : ')
    print('     No. of images : 2000')
    print('     Input size to the CNN model : 128*128') 
    print('Testing dataset : ')
    print('     No. of images : 120')
    print('     Input size to the CNN model : 128*128')
    model=define_model() 
    model=compile_fit_model(model) 
    model.save("./model.h5")
    x_test=np.load('../input/breast-cancer-detection-dcnn/test_dataset/x_test.npy')
    y_test=np.load('../input/breast-cancer-detection-dcnn/test_dataset/y_test.npy')
    print('\nEvalation with testing dataset: ')
    score = model.evaluate(x_test, y_test, verbose=2) 
    print('Test accuracy : ', score[1]*100,'%')  
    cm_plot_label =['benign', 'malignant'] # 0 - benign, 1 - malignant
    y_predict = model.predict(x_test).argmax(axis=1)
    cm=confusion_matrix(y_test.argmax(axis=-1), y_predict, normalize='true')
    plot_normalized_confusion_matrix(cm, cm_plot_label, title ='Normalized Confusion Matrix')
    
if __name__ == "__main__":
        main()
# Out:
# Training dataset :
#      No. of images : 2000
#      Input size to the CNN model : 128*128
# Testing dataset :
#      No. of images : 120
#      Input size to the CNN model : 128*128
# 2022-02-17 08:13:33.842726: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-17 08:13:33.933152: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-17 08:13:33.933905: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-17 08:13:33.935152: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-02-17 08:13:33.936021: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-17 08:13:33.936690: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-17 08:13:33.937328: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-17 08:13:35.543627: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-17 08:13:35.544437: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-17 08:13:35.545085: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-17 08:13:35.545647: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# CNN model :
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 42, 42, 4)         104
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 21, 21, 4)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 9, 9, 4)           404
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 4)           0
# _________________________________________________________________
# flatten (Flatten)            (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 4)                 1028
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 10
# =================================================================
# Total params: 1,546
# Trainable params: 1,546
# Non-trainable params: 0
# _________________________________________________________________
#
# Training the dataset :
# 2022-02-17 08:13:38.880879: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/50
# 2022-02-17 08:13:40.272281: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 50/50 [==============================] - 7s 8ms/step - loss: 0.6946 - accuracy: 0.5031 - val_loss: 0.6951 - val_accuracy: 0.4925
# Epoch 2/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.6941 - accuracy: 0.4975 - val_loss: 0.6947 - val_accuracy: 0.4925
# Epoch 3/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6931 - accuracy: 0.5219 - val_loss: 0.6948 - val_accuracy: 0.5075
# Epoch 4/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6947 - accuracy: 0.4894 - val_loss: 0.6941 - val_accuracy: 0.4925
# Epoch 5/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6943 - accuracy: 0.5119 - val_loss: 0.6944 - val_accuracy: 0.4925
# Epoch 6/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6939 - accuracy: 0.5069 - val_loss: 0.6933 - val_accuracy: 0.5075
# Epoch 7/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6944 - accuracy: 0.4931 - val_loss: 0.6931 - val_accuracy: 0.5075
# Epoch 8/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6944 - accuracy: 0.4969 - val_loss: 0.6935 - val_accuracy: 0.5075
# Epoch 9/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.6942 - accuracy: 0.4919 - val_loss: 0.6934 - val_accuracy: 0.5075
# Epoch 10/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6942 - accuracy: 0.4956 - val_loss: 0.6938 - val_accuracy: 0.4925
# Epoch 11/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6942 - accuracy: 0.4919 - val_loss: 0.6944 - val_accuracy: 0.4925
# Epoch 12/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6947 - accuracy: 0.4894 - val_loss: 0.6964 - val_accuracy: 0.4925
# Epoch 13/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6948 - accuracy: 0.4806 - val_loss: 0.6934 - val_accuracy: 0.5075
# Epoch 14/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6942 - accuracy: 0.4894 - val_loss: 0.6937 - val_accuracy: 0.4925
# Epoch 15/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6935 - accuracy: 0.5106 - val_loss: 0.6948 - val_accuracy: 0.4925
# Epoch 16/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6945 - accuracy: 0.4969 - val_loss: 0.6936 - val_accuracy: 0.5075
# Epoch 17/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.6942 - accuracy: 0.4956 - val_loss: 0.6941 - val_accuracy: 0.4925
# Epoch 18/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6947 - accuracy: 0.4819 - val_loss: 0.6939 - val_accuracy: 0.4925
# Epoch 19/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.6949 - accuracy: 0.4806 - val_loss: 0.6931 - val_accuracy: 0.5075
# Epoch 20/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6940 - accuracy: 0.4956 - val_loss: 0.6951 - val_accuracy: 0.4925
# Epoch 21/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.6949 - accuracy: 0.4831 - val_loss: 0.6932 - val_accuracy: 0.4925
# Epoch 22/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6941 - accuracy: 0.4869 - val_loss: 0.6931 - val_accuracy: 0.5075
# Epoch 23/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.6946 - accuracy: 0.4756 - val_loss: 0.6932 - val_accuracy: 0.4925
# Epoch 24/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6932 - accuracy: 0.5231 - val_loss: 0.6936 - val_accuracy: 0.5075
# Epoch 25/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6943 - accuracy: 0.4906 - val_loss: 0.6930 - val_accuracy: 0.5075
# Epoch 26/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6941 - accuracy: 0.4919 - val_loss: 0.6933 - val_accuracy: 0.4925
# Epoch 27/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.6946 - accuracy: 0.4856 - val_loss: 0.6931 - val_accuracy: 0.5075
# Epoch 28/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6948 - accuracy: 0.4919 - val_loss: 0.6942 - val_accuracy: 0.4925
# Epoch 29/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6941 - accuracy: 0.4831 - val_loss: 0.6933 - val_accuracy: 0.4925
# Epoch 30/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6944 - accuracy: 0.5006 - val_loss: 0.6930 - val_accuracy: 0.5075
# Epoch 31/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.6939 - accuracy: 0.5069 - val_loss: 0.6935 - val_accuracy: 0.4925
# Epoch 32/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.6942 - accuracy: 0.4906 - val_loss: 0.6937 - val_accuracy: 0.4925
# Epoch 33/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.6940 - accuracy: 0.4906 - val_loss: 0.6931 - val_accuracy: 0.5075
# Epoch 34/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.6949 - accuracy: 0.4769 - val_loss: 0.6930 - val_accuracy: 0.5075
# Epoch 35/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6942 - accuracy: 0.4894 - val_loss: 0.6930 - val_accuracy: 0.5075
# Epoch 36/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.6943 - accuracy: 0.4981 - val_loss: 0.6932 - val_accuracy: 0.5075
# Epoch 37/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6940 - accuracy: 0.4881 - val_loss: 0.6940 - val_accuracy: 0.4925
# Epoch 38/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6946 - accuracy: 0.4769 - val_loss: 0.6935 - val_accuracy: 0.4925
# Epoch 39/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6946 - accuracy: 0.4906 - val_loss: 0.6932 - val_accuracy: 0.5075
# Epoch 40/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6945 - accuracy: 0.4794 - val_loss: 0.6931 - val_accuracy: 0.5075
# Epoch 41/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.6943 - accuracy: 0.4837 - val_loss: 0.6939 - val_accuracy: 0.4925
# Epoch 42/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6940 - accuracy: 0.5006 - val_loss: 0.6956 - val_accuracy: 0.4925
# Epoch 43/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6942 - accuracy: 0.4906 - val_loss: 0.6931 - val_accuracy: 0.5075
# Epoch 44/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.6938 - accuracy: 0.5106 - val_loss: 0.6939 - val_accuracy: 0.5075
# Epoch 45/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.6943 - accuracy: 0.4931 - val_loss: 0.6931 - val_accuracy: 0.5075
# Epoch 46/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6943 - accuracy: 0.4844 - val_loss: 0.6949 - val_accuracy: 0.4925
# Epoch 47/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6942 - accuracy: 0.5069 - val_loss: 0.6945 - val_accuracy: 0.4925
# Epoch 48/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6941 - accuracy: 0.4956 - val_loss: 0.6931 - val_accuracy: 0.5075
# Epoch 49/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6939 - accuracy: 0.5044 - val_loss: 0.6950 - val_accuracy: 0.4925
# Epoch 50/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6943 - accuracy: 0.5044 - val_loss: 0.6945 - val_accuracy: 0.4925
# Graph of epochs vs loss
# Evalation with testing dataset:
# 4/4 - 0s - loss: 0.6939 - accuracy: 0.5000
# Test accuracy :  50.0 %
# Confusion matrix, with normalization
# [[0. 1.]
#  [0. 1.]]
